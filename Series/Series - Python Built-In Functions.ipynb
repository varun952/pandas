# %% [markdown]
# ## Python Built-In Functions

# %%
import os
import pandas as pd

# %%
os.chdir("/home/mediaworker/anaconda2/envs/pandas_playground/")

# %%
google_ps = pd.read_csv("datasets/google_stock_price.csv", squeeze=True)

# %%
type(google_ps)
# Out:
# pandas.core.series.Series

# %%
# Sort google data set values in ascening order
sorted(google_ps)
# Out:
# [49.95,
#  50.07,
#  50.12,
#  50.7,
#  50.74,
#  50.95,
#  51.1,
#  51.1,
#  51.13,
#  52.38,
#  52.61,
#  52.95,
#  53.02,
#  53.7,
#  53.9,
#  54.1,
#  54.65,
#  55.69,
#  55.94,
#  56.93,
#  58.69,
#  58.86,
#  59.07,
#  59.13,
#  59.62,
#  59.86,
#  60.35,
#  63.37,
#  64.74,
#  65.47,
#  66.22,
#  67.46,
#  67.56,
#  68.47,
#  68.63,
#  68.8,
#  69.12,
#  69.36,
#  70.17,
#  70.38,
#  70.93,
#  71.98,
#  73.9,
#  74.51,
#  74.62,
#  82.47,
#  83.68,
#  83.69,
#  83.85,
#  84.27,
#  84.59,
#  84.62,
#  84.91,
#  85.14,
#  85.63,
#  85.74,
#  86.13,
#  86.16,
#  86.19,
#  86.19,
#  86.63,
#  87.29,
#  87.41,
#  87.71,
#  88.06,
#  88.15,
#  88.47,
#  88.81,
#  89.21,
#  89.22,
#  89.26,
#  89.4,
#  89.54,
#  89.56,
#  89.61,
#  89.61,
#  89.7,
#  89.8,
#  89.89,
#  89.9,
#  89.93,
#  89.93,
#  89.95,
#  90.11,
#  90.13,
#  90.16,
#  90.27,
#  90.35,
#  90.43,
#  90.58,
#  90.62,
#  90.81,
#  90.9,
#  90.91,
#  91.42,
#  91.78,
#  92.26,
#  92.34,
#  92.41,
#  92.42,
#  92.5,
# ...

# %%
# convert pandas series to python list
google_list = list(google_ps)
type(google_list)
# Out:
# list

# %%
# convert pandas series to python dict
google_dict = dict(google_ps)
type(google_dict)
# Out:
# dict

# %%
# get max value from padas series
google_ds_max = max(google_ps)
google_ds_max
# Out:
# 782.22

# %%
# get min value from padas series
google_ds_min = min(google_ps)
google_ds_min
# Out:
# 49.95
