# %%
import os
import pandas as pd

os.chdir("/home/mediaworker/anaconda2/envs/pandas_playground/")

# syntax 2
# while reading from csv itself one can specify to parse_dates
df = pd.read_csv("datasets/jamesbond.csv")

df.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %% [markdown]
# ## set_index() and reset_index Methods
#
# ### Set user defined index for dataframe

# %%
# syntax 1
df = pd.read_csv("datasets/jamesbond.csv")
df.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
df.set_index(keys="Film", inplace=True)
df.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
# reverse the above operation  of setting Film
# column as dataframe index
df.reset_index(inplace=True)
df.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
df.set_index("Year", drop=False)
# Out:
#                                  Film  Year           Actor  \
# Year
# 1962                           Dr. No  1962    Sean Connery
# 1963            From Russia with Love  1963    Sean Connery
# 1964                       Goldfinger  1964    Sean Connery
# 1965                      Thunderball  1965    Sean Connery
# 1967                    Casino Royale  1967     David Niven
# 1967              You Only Live Twice  1967    Sean Connery
# 1969  On Her Majesty's Secret Service  1969  George Lazenby
# 1971             Diamonds Are Forever  1971    Sean Connery
# 1973                 Live and Let Die  1973     Roger Moore
# 1974      The Man with the Golden Gun  1974     Roger Moore
# 1977             The Spy Who Loved Me  1977     Roger Moore
# 1979                        Moonraker  1979     Roger Moore
# 1981               For Your Eyes Only  1981     Roger Moore
# 1983            Never Say Never Again  1983    Sean Connery
# ...
